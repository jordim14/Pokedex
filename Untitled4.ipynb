# %%
import numpy as np
import pandas as pd
from sklearn.metrics import r2_score
from sklearn import linear_model
import numpy as np, statsmodels.stats.api as sms

# %%
Pokedex = pd.read_csv('pokedex_(Update_05.20).csv')

# %%
Pokedex = Pokedex.drop(['Unnamed: 0'], axis=1)
Pokedex.head()
# Out:
#    pokedex_number           name german_name        japanese_name  generation  \
# 0               1      Bulbasaur     Bisasam  フシギダネ (Fushigidane)           1
# 1               2        Ivysaur   Bisaknosp   フシギソウ (Fushigisou)           1
# 2               3       Venusaur    Bisaflor  フシギバナ (Fushigibana)           1
# 3               3  Mega Venusaur    Bisaflor  フシギバナ (Fushigibana)           1
# 4               4     Charmander    Glumanda      ヒトカゲ (Hitokage)           1
#
#    status         species  type_number type_1  type_2  ...  against_ground  \
# 0  Normal    Seed Pokémon            2  Grass  Poison  ...             1.0
# 1  Normal    Seed Pokémon            2  Grass  Poison  ...             1.0
# 2  Normal    Seed Pokémon            2  Grass  Poison  ...             1.0
# 3  Normal    Seed Pokémon            2  Grass  Poison  ...             1.0
# 4  Normal  Lizard Pokémon            1   Fire     NaN  ...             2.0
#
#    against_flying  against_psychic against_bug against_rock against_ghost  \
# 0             2.0              2.0         1.0          1.0           1.0
# 1             2.0              2.0         1.0          1.0           1.0
# 2             2.0              2.0         1.0          1.0           1.0
# 3             2.0              2.0         1.0          1.0           1.0
# 4             1.0              1.0         0.5          2.0           1.0
#
#    against_dragon  against_dark  against_steel  against_fairy
# 0             1.0           1.0            1.0            0.5
# 1             1.0           1.0            1.0            0.5
# 2             1.0           1.0            1.0            0.5
# 3             1.0           1.0            1.0            0.5
# 4             1.0           1.0            0.5            0.5
#
# [5 rows x 50 columns]

# %%
Pokedex.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1028 entries, 0 to 1027
# Data columns (total 50 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   pokedex_number    1028 non-null   int64
#  1   name              1028 non-null   object
#  2   german_name       938 non-null    object
#  3   japanese_name     938 non-null    object
#  4   generation        1028 non-null   int64
#  5   status            1028 non-null   object
#  6   species           1028 non-null   object
#  7   type_number       1028 non-null   int64
#  8   type_1            1028 non-null   object
#  9   type_2            542 non-null    object
#  10  height_m          1028 non-null   float64
#  11  weight_kg         1027 non-null   float64
#  12  abilities_number  1028 non-null   int64
#  13  ability_1         1025 non-null   object
#  14  ability_2         513 non-null    object
#  15  ability_hidden    810 non-null    object
#  16  total_points      1028 non-null   float64
#  17  hp                1028 non-null   float64
#  18  attack            1028 non-null   float64
#  19  defense           1028 non-null   float64
#  20  sp_attack         1028 non-null   float64
#  21  sp_defense        1028 non-null   float64
#  22  speed             1028 non-null   float64
#  23  catch_rate        924 non-null    float64
#  24  base_friendship   924 non-null    float64
#  25  base_experience   924 non-null    float64
#  26  growth_rate       1027 non-null   object
#  27  egg_type_number   1028 non-null   int64
#  28  egg_type_1        1025 non-null   object
#  29  egg_type_2        282 non-null    object
#  30  percentage_male   792 non-null    float64
#  31  egg_cycles        1027 non-null   float64
#  32  against_normal    1028 non-null   float64
#  33  against_fire      1028 non-null   float64
#  34  against_water     1028 non-null   float64
#  35  against_electric  1028 non-null   float64
#  36  against_grass     1028 non-null   float64
#  37  against_ice       1028 non-null   float64
#  38  against_fight     1028 non-null   float64
#  39  against_poison    1028 non-null   float64
#  40  against_ground    1028 non-null   float64
#  41  against_flying    1028 non-null   float64
#  42  against_psychic   1028 non-null   float64
#  43  against_bug       1028 non-null   float64
#  44  against_rock      1028 non-null   float64
#  45  against_ghost     1028 non-null   float64
#  46  against_dragon    1028 non-null   float64
#  47  against_dark      1028 non-null   float64
#  48  against_steel     1028 non-null   float64
#  49  against_fairy     1028 non-null   float64
# dtypes: float64(32), int64(5), object(13)
# memory usage: 401.7+ KB

# %%
nulls_summary = pd.DataFrame(Pokedex.isnull().any(), columns=['Nulls'])   
nulls_summary['Num_of_nulls [qty]'] = pd.DataFrame(Pokedex.isnull().sum())   
nulls_summary['Num_of_nulls [%]'] = round((Pokedex.isnull().mean()*100),2)   
print(nulls_summary)
# Out:
#                   Nulls  Num_of_nulls [qty]  Num_of_nulls [%]
# pokedex_number    False                   0              0.00
# name              False                   0              0.00
# german_name        True                  90              8.75
# japanese_name      True                  90              8.75
# generation        False                   0              0.00
# status            False                   0              0.00
# species           False                   0              0.00
# type_number       False                   0              0.00
# type_1            False                   0              0.00
# type_2             True                 486             47.28
# height_m          False                   0              0.00
# weight_kg          True                   1              0.10
# abilities_number  False                   0              0.00
# ability_1          True                   3              0.29
# ability_2          True                 515             50.10
# ability_hidden     True                 218             21.21
# total_points      False                   0              0.00
# hp                False                   0              0.00
# attack            False                   0              0.00
# defense           False                   0              0.00
# sp_attack         False                   0              0.00
# sp_defense        False                   0              0.00
# speed             False                   0              0.00
# catch_rate         True                 104             10.12
# base_friendship    True                 104             10.12
# base_experience    True                 104             10.12
# growth_rate        True                   1              0.10
# egg_type_number   False                   0              0.00
# egg_type_1         True                   3              0.29
# egg_type_2         True                 746             72.57
# percentage_male    True                 236             22.96
# egg_cycles         True                   1              0.10
# against_normal    False                   0              0.00
# against_fire      False                   0              0.00
# against_water     False                   0              0.00
# against_electric  False                   0              0.00
# against_grass     False                   0              0.00
# against_ice       False                   0              0.00
# against_fight     False                   0              0.00
# against_poison    False                   0              0.00
# against_ground    False                   0              0.00
# against_flying    False                   0              0.00
# against_psychic   False                   0              0.00
# against_bug       False                   0              0.00
# against_rock      False                   0              0.00
# against_ghost     False                   0              0.00
# against_dragon    False                   0              0.00
# against_dark      False                   0              0.00
# against_steel     False                   0              0.00
# against_fairy     False                   0              0.00

# %%
Pokedex[Pokedex['german_name'].isna()]
# Out:
#       pokedex_number                            name german_name  \
# 938              808                          Meltan         NaN
# 939              809                        Melmetal         NaN
# 940              810                         Grookey         NaN
# 941              811                        Thwackey         NaN
# 942              812                       Rillaboom         NaN
# ...              ...                             ...         ...
# 1023             888     Zacian Hero of Many Battles         NaN
# 1024             889        Zamazenta Crowned Shield         NaN
# 1025             889  Zamazenta Hero of Many Battles         NaN
# 1026             890                       Eternatus         NaN
# 1027             890             Eternatus Eternamax         NaN
#
#      japanese_name  generation     status           species  type_number  \
# 938            NaN           7   Mythical   Hex Nut Pokémon            1
# 939            NaN           7   Mythical   Hex Nut Pokémon            1
# 940            NaN           8     Normal     Chimp Pokémon            1
# 941            NaN           8     Normal      Beat Pokémon            1
# 942            NaN           8     Normal   Drummer Pokémon            1
# ...            ...         ...        ...               ...          ...
# 1023           NaN           8  Legendary   Warrior Pokémon            1
# 1024           NaN           8  Legendary   Warrior Pokémon            2
# 1025           NaN           8  Legendary   Warrior Pokémon            1
# 1026           NaN           8  Legendary  Gigantic Pokémon            2
# 1027           NaN           8  Legendary  Gigantic Pokémon            2
#
#         type_1  type_2  ...  against_ground  against_flying  against_psychic  \
# 938      Steel     NaN  ...             2.0             0.5              0.5
# 939      Steel     NaN  ...             2.0             0.5              0.5
# 940      Grass     NaN  ...             0.5             2.0              1.0
# 941      Grass     NaN  ...             0.5             2.0              1.0
# 942      Grass     NaN  ...             0.5             2.0              1.0
# ...        ...     ...  ...             ...             ...              ...
# 1023     Fairy     NaN  ...             1.0             1.0              1.0
# 1024  Fighting   Steel  ...             2.0             1.0              1.0
# 1025  Fighting     NaN  ...             1.0             2.0              2.0
# 1026    Poison  Dragon  ...             2.0             1.0              2.0
# 1027    Poison  Dragon  ...             2.0             1.0              2.0
#
#      against_bug against_rock against_ghost  against_dragon  against_dark  \
# 938         0.50         0.50           1.0             0.5           1.0
# 939         0.50         0.50           1.0             0.5           1.0
# 940         2.00         1.00           1.0             1.0           1.0
# 941         2.00         1.00           1.0             1.0           1.0
# 942         2.00         1.00           1.0             1.0           1.0
# ...          ...          ...           ...             ...           ...
# 1023        0.50         1.00           1.0             0.0           0.5
# 1024        0.25         0.25           1.0             0.5           0.5
# 1025        0.50         0.50           1.0             1.0           0.5
# 1026        0.50         1.00           1.0             2.0           1.0
# 1027        0.50         1.00           1.0             2.0           1.0
#
#       against_steel  against_fairy
# 938             0.5            0.5
# 939             0.5            0.5
# 940             1.0            1.0
# 941             1.0            1.0
# 942             1.0            1.0
# ...             ...            ...
# 1023            2.0            1.0
# 1024            0.5            1.0
# 1025            1.0            2.0
# 1026            1.0            1.0
# 1027            1.0            1.0
#
# [90 rows x 50 columns]

# %%
Pokedex = Pokedex.drop(['german_name'], axis=1)
Pokedex = Pokedex.drop(['japanese_name'], axis=1)

# %%
Zero_count = pd.DataFrame(Pokedex.isin([0]).any(), columns=['Zero'])   
Zero_count['Num_of_zero [qty]'] = pd.DataFrame(Pokedex.isin([0]).sum())   
Zero_count['Num_of_zero [%]'] = round((Pokedex.isin([0]).mean()*100),2)   
print(Zero_count)
# Out:
#                    Zero  Num_of_zero [qty]  Num_of_zero [%]
# pokedex_number    False                  0             0.00
# name              False                  0             0.00
# generation        False                  0             0.00
# status            False                  0             0.00
# species           False                  0             0.00
# type_number       False                  0             0.00
# type_1            False                  0             0.00
# type_2            False                  0             0.00
# height_m          False                  0             0.00
# weight_kg         False                  0             0.00
# abilities_number   True                  1             0.10
# ability_1         False                  0             0.00
# ability_2         False                  0             0.00
# ability_hidden    False                  0             0.00
# total_points      False                  0             0.00
# hp                False                  0             0.00
# attack            False                  0             0.00
# defense           False                  0             0.00
# sp_attack         False                  0             0.00
# sp_defense        False                  0             0.00
# speed             False                  0             0.00
# catch_rate        False                  0             0.00
# base_friendship    True                 58             5.64
# base_experience   False                  0             0.00
# growth_rate       False                  0             0.00
# egg_type_number    True                  3             0.29
# egg_type_1        False                  0             0.00
# egg_type_2        False                  0             0.00
# percentage_male    True                 31             3.02
# egg_cycles        False                  0             0.00
# against_normal     True                 66             6.42
# against_fire       True                 13             1.26
# against_water      True                 16             1.56
# against_electric   True                 96             9.34
# against_grass      True                  6             0.58
# against_ice        True                  1             0.10
# against_fight      True                 66             6.42
# against_poison     True                 72             7.00
# against_ground     True                157            15.27
# against_flying    False                  0             0.00
# against_psychic    True                 71             6.91
# against_bug        True                  1             0.10
# against_rock      False                  0             0.00
# against_ghost      True                126            12.26
# against_dragon     True                 62             6.03
# against_dark      False                  0             0.00
# against_steel      True                  1             0.10
# against_fairy      True                  1             0.10

# %%
Pokedex.describe().T
# Out:
#                    count        mean         std     min     25%    50%  \
# pokedex_number    1028.0  437.711089  259.366480    1.00  213.75  433.5
# generation        1028.0    4.034047    2.234937    1.00    2.00    4.0
# type_number       1028.0    1.527237    0.499501    1.00    1.00    2.0
# height_m          1028.0    1.368093    3.380126    0.10    0.60    1.0
# weight_kg         1027.0   69.753749  129.221230    0.10    8.80   28.5
# abilities_number  1028.0    2.284047    0.794981    0.00    2.00    2.0
# total_points      1028.0  437.571984  121.664910  175.00  330.00  455.0
# hp                1028.0   69.577821   26.385849    1.00   50.00   66.5
# attack            1028.0   80.119650   32.372321    5.00   55.00   76.0
# defense           1028.0   74.475681   31.303309    5.00   50.00   70.0
# sp_attack         1028.0   72.732490   32.677698   10.00   50.00   65.0
# sp_defense        1028.0   72.132296   28.083684   20.00   50.00   70.0
# speed             1028.0   68.534047   29.802103    5.00   45.00   65.0
# catch_rate         924.0   93.172078   75.240630    3.00   45.00   60.0
# base_friendship    924.0   64.139610   21.455464    0.00   70.00   70.0
# base_experience    924.0  153.814935   79.270628   36.00   67.00  159.0
# egg_type_number   1028.0    1.271401    0.451417    0.00    1.00    1.0
# percentage_male    792.0   55.003157   20.182675    0.00   50.00   50.0
# egg_cycles        1027.0   30.316456   28.942912    5.00   20.00   20.0
# against_normal    1028.0    0.868434    0.286236    0.00    1.00    1.0
# against_fire      1028.0    1.125486    0.717742    0.00    0.50    1.0
# against_water     1028.0    1.053502    0.613411    0.00    0.50    1.0
# against_electric  1028.0    1.034290    0.645167    0.00    0.50    1.0
# against_grass     1028.0    1.004134    0.748527    0.00    0.50    1.0
# against_ice       1028.0    1.196498    0.759471    0.00    0.50    1.0
# against_fight     1028.0    1.078794    0.754969    0.00    0.50    1.0
# against_poison    1028.0    0.952335    0.542982    0.00    0.50    1.0
# against_ground    1028.0    1.084630    0.784937    0.00    0.50    1.0
# against_flying    1028.0    1.166342    0.593030    0.25    1.00    1.0
# against_psychic   1028.0    0.979329    0.499146    0.00    1.00    1.0
# against_bug       1028.0    0.992461    0.598301    0.00    0.50    1.0
# against_rock      1028.0    1.239786    0.699156    0.25    1.00    1.0
# against_ghost     1028.0    1.010700    0.558533    0.00    1.00    1.0
# against_dragon    1028.0    0.975681    0.377549    0.00    1.00    1.0
# against_dark      1028.0    1.065661    0.451054    0.25    1.00    1.0
# against_steel     1028.0    0.980302    0.503434    0.00    0.50    1.0
# against_fairy     1028.0    1.084874    0.527743    0.00    1.00    1.0
#
#                       75%     max
# pokedex_number    663.250   890.0
# generation          6.000     8.0
# type_number         2.000     2.0
# height_m            1.500   100.0
# weight_kg          69.100   999.9
# abilities_number    3.000     3.0
# total_points      510.000  1125.0
# hp                 80.000   255.0
# attack            100.000   190.0
# defense            90.000   250.0
# sp_attack          95.000   194.0
# sp_defense         90.000   250.0
# speed              90.000   180.0
# catch_rate        127.000   255.0
# base_friendship    70.000   140.0
# base_experience   201.500   608.0
# egg_type_number     2.000     2.0
# percentage_male    50.000   100.0
# egg_cycles         25.000   120.0
# against_normal      1.000     1.0
# against_fire        2.000     4.0
# against_water       1.000     4.0
# against_electric    1.000     4.0
# against_grass       1.000     4.0
# against_ice         2.000     4.0
# against_fight       2.000     4.0
# against_poison      1.000     4.0
# against_ground      1.625     4.0
# against_flying      1.000     4.0
# against_psychic     1.000     4.0
# against_bug         1.000     4.0
# against_rock        2.000     4.0
# against_ghost       1.000     4.0
# against_dragon      1.000     2.0
# against_dark        1.000     4.0
# against_steel       1.000     4.0
# against_fairy       1.000     4.0

# %%
Pokedex['type_2'] = Pokedex['type_2'].fillna('Ninguno')
Pokedex['ability_2'] = Pokedex['ability_2'].fillna('Ninguno')
Pokedex['ability_hidden'] = Pokedex['ability_hidden'].fillna('Ninguno')
Pokedex['egg_type_2'] = Pokedex['egg_type_2'].fillna('Ninguno')

# %%
Pokedex['catch_rate'].fillna(Pokedex['catch_rate'].mean(), inplace=True)
Pokedex['base_experience'].fillna(Pokedex['base_experience'].mean(), inplace=True)
Pokedex['base_friendship'].fillna(Pokedex['base_friendship'].mean(), inplace=True)
Pokedex['percentage_male'].fillna(Pokedex['percentage_male'].mean(), inplace=True)
Pokedex['weight_kg'].fillna(Pokedex['weight_kg'].mean(), inplace=True)

# %%
Pokedex2 = Pokedex.dropna()

# %%
Pokedex2.to_csv("Pokedex.csv")

# %%
Pokedex_filter = Pokedex2[[ 'name', 'generation', 'status', 'species',
       'type_number',  'height_m', 'weight_kg',
       'abilities_number',   'total_points', 'hp', 'attack', 'defense', 'sp_attack', 'sp_defense',
       'speed', 'catch_rate']]

# %%
# Shapiro-Wilk Test
from numpy.random import seed
from numpy.random import randn
from scipy.stats import shapiro
# seed the random number generator
seed(1)
# generate univariate observations
data = Pokedex[['generation',
       'type_number',  'height_m', 'weight_kg',
       'abilities_number',       'total_points', 'hp', 'attack', 'defense', 'sp_attack', 'sp_defense',
       'speed', 'catch_rate']]
# normality test
for i in list(data.columns):
    var = data[i]
    print(i)
    stat, p = shapiro(var)
    print('Statistics=%.3f, p=%.3f' % (stat, p))
    # interpret
    alpha = 0.05
    if p > alpha:
        print('Sample looks Gaussian (fail to reject H0)')
    else:
        print('Sample does not look Gaussian (reject H0)')
# Out:
# generation
# Statistics=0.925, p=0.000
# Sample does not look Gaussian (reject H0)
# type_number
# Statistics=0.636, p=0.000
# Sample does not look Gaussian (reject H0)
# height_m
# Statistics=0.161, p=0.000
# Sample does not look Gaussian (reject H0)
# weight_kg
# Statistics=0.511, p=0.000
# Sample does not look Gaussian (reject H0)
# abilities_number
# Statistics=0.759, p=0.000
# Sample does not look Gaussian (reject H0)
# total_points
# Statistics=0.977, p=0.000
# Sample does not look Gaussian (reject H0)
# hp
# Statistics=0.894, p=0.000
# Sample does not look Gaussian (reject H0)
# attack
# Statistics=0.982, p=0.000
# Sample does not look Gaussian (reject H0)
# defense
# Statistics=0.936, p=0.000
# Sample does not look Gaussian (reject H0)
# sp_attack
# Statistics=0.960, p=0.000
# Sample does not look Gaussian (reject H0)
# sp_defense
# Statistics=0.955, p=0.000
# Sample does not look Gaussian (reject H0)
# speed
# Statistics=0.983, p=0.000
# Sample does not look Gaussian (reject H0)
# catch_rate
# Statistics=0.856, p=0.000
# Sample does not look Gaussian (reject H0)

# %%
# define the data/predictors as the pre-set feature names  
df = pd.DataFrame(Pokedex2[['generation', 'status', 'species', 'type_number',  'height_m', 'weight_kg',
       'abilities_number', 
'hp', 'attack', 'defense', 'sp_attack', 'sp_defense',
       'speed']])

# Put the target (housing value -- MEDV) in another DataFrame
target = pd.DataFrame(Pokedex_filter.catch_rate)

# %%
df = pd.get_dummies(df, columns=['status', 'species'])

# %%
lm = linear_model.LinearRegression()
model = lm.fit(df,target)

# %%
predictions = lm.predict(df)
print(predictions)
# Out:
# [[117.36132812]
#  [ 79.11914062]
#  [ 35.90625   ]
#  ...
#  [120.65625   ]
#  [ 92.18945312]
#  [ 93.15039062]]

# %%
r2_score(target, predictions)
# Out:
# 0.8686975060361204

# %%
cm = sms.CompareMeans(sms.DescrStatsW(Pokedex_filter[Pokedex_filter['status']=='Legendary'].total_points), sms.DescrStatsW(Pokedex_filter[Pokedex_filter['status']=='Normal'].total_points))
print (cm.tconfint_diff(usevar='unequal'))
# Out:
# (217.5528519004007, 288.06118318731865)
